# %% [markdown]
# # Custom Named Entity Recognition

# %% [markdown]
# ## Fisrt we need to extract usernames of followers from twitter
# We are using the packages tweepy,csv,time etc.
# In the fisrt step we extract usernames of followers of a user.
# Here i have used profile of Narendra Modi.
# We store these names in a csv file named results.
# This process takes a long time.

# %%
import time
import tweepy
import csv

from secrets import *

consumer_key ='GLEPvDdlbQKYxIHZ4lmc***'
consumer_secret='pUVpOsLfL4AVQIZjb7q87xht2JcS1qMpy5rJcLbHMGCeip***'
access_token='736518106806243328-NKGyh8N5z5LTwrKjFLno9K27*****'
access_token_secret='0A00HlShtkgyFZ6ms9HO0X5YYu5cQXxiErfrdTWO*****'

auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

users = tweepy.Cursor(api.followers, screen_name="narendramodi").items()


HEADER = ['Screenname']


def processing_loop(csvfile):
    csv_writer = csv.writer(csvfile)
    csv_writer.writerow(HEADER)

    while True:
        try:
            user = next(users)
        except tweepy.TweepError:
            time.sleep(60*20)
            user = next(users)
        except StopIteration:
            break
        csv_writer.writerow([user.screen_name])
        csvfile.flush()
        time.sleep(5)

with open('results.csv', 'w') as csvfile:
    processing_loop(csvfile)

# %%
#We read the csv file
import csv
with open('results.csv') as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    for row in readCSV:
        print(row)
# Out:
# ['Screenname']
# ['JITENDR61607298']
# ['debashisachar20']
# ['geetkhadayat1']
# ['ArunSinghSikar5']
# ['schlichting1103']
# ['Shubham40781568']
# ['Chandra76492314']
# ['RahulSh34379401']
# ['Sanjaya86659869']
# ['sharadhavenkat3']
# ['Hotujjayi']
# ['eliyachh']
# ['DSaiKrishna1995']
# ['wealthyfeed']
# ['AshishK02882535']
# ['laljipandya1']
# ['johnnarlin']
# ['pk_imc']
# ['BabuLal51598292']
# ['Pushpan33559883']
# ['MDUUpEJ5ZbXNypn']
# ['AVasaiya']
# ['AaronHui8']
# ['PapiyaGoswami']
# ['PankajK01854044']
# ['KhapekarNavin']
# ['S35555177']
# ['shokotokkotoki']
# ['RamNara07451582']
# ['alugoluRamNaidu']
# ['Jakirhu39846102']
# ['sarojKo81024746']
# ['LimbicMovement']
# ['TChahankar']
# ['ArunNeetha']
# ['IrfanNaam']
# ['KartikY72860388']
# ['BKumbsr']
# ['M21015262']
# ['SnakeHu75417276']
# ['adweat_mishra']
# ['Nozomi_llru']
# ['DeepakGogoi18']
# ['SurajGu62095760']
# ['DrAnshulJain3']
# ['HarryMa96051064']
# ['IasJinesh']
# ['neha_a_dreamer']
# ['VVBARI1']
# ['zzxNuclearxzz']
# ...
